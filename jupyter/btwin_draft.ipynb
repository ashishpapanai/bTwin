# %% [markdown]
# ## bTwin [Draft]
#
# bTwin is an acronym for Bollywood Twin. The idea is to let the user find his celebrity twin by using the technique of computer vision using convolution neural networks (CNNs).
#
# The current dataset is a collection of pictures of top 100 celebrities of bollywood listed by hungama.com.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data.csv')
df.head()
# Out:
#    Label  Pixel1  Pixel2  Pixel3  Pixel4  Pixel5  Pixel6  Pixel7  Pixel8  \
# 0      1      40      39      37      27      37      36      50      43
# 1      1     220     199     173     145     132     130     125     126
# 2      1     213     213     211     214     212     215     226     226
# 3      1      88      88      88      88      88      88      88      88
# 4      1      37      42      46      44      37      32      33      37
#
#    Pixel9  ...  Pixel9991  Pixel9992  Pixel9993  Pixel9994  Pixel9995  \
# 0      41  ...         63         66         69         67         64
# 1     122  ...         93         77         75         75         72
# 2     226  ...         50         51         52         52         51
# 3      88  ...         89        105        108        103        106
# 4      43  ...        104        190        180        185        183
#
#    Pixel9996  Pixel9997  Pixel9998  Pixel9999  Pixel10000
# 0         67         71         70         63          60
# 1         84         88         79         86          86
# 2         53         51         51         51          53
# 3        106        105        103        101          98
# 4        182        184        185        186         187
#
# [5 rows x 10001 columns]

# %%
train, validate, test = np.split(df.sample(frac=1, random_state=42), [int(.6*len(df)), int(.8*len(df))])

# %%
print("Training Data: ")
print(train)
print("Validation Data: ")
print(validate)
print("Test Data: ")
print(test)
# Out:
# Training Data:
#        Label  Pixel1  Pixel2  Pixel3  Pixel4  Pixel5  Pixel6  Pixel7  Pixel8  \
# 11482     95      70      66      71      85      64      61      67      61
# 5323      43       1       1       1       1       1       1       1       1
# 824        8       0       0       0       0       0       0       0       0
# 8833      73     157     158     167     166     162     161     156     169
# 1830      15      28      35      36      29      26      27      30      29
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 10077     83     162     191     221     219     203     182     141     106
# 3280      27     152     153     155     157     159     160     161     161
# 3472      28     146     142     140     158     159     150     155     152
# 6192      50     135     135     133     131     136     145     151     152
# 10780     90      23      28      36      37      38      35      27      30
#
#        Pixel9  ...  Pixel9991  Pixel9992  Pixel9993  Pixel9994  Pixel9995  \
# 11482      62  ...        160        181        194        219        222
# 5323        1  ...          4          5          4          3          1
# 824         0  ...          0          0          0          0          0
# 8833      165  ...          0          8         21         27         58
# 1830       26  ...        125         86         20          2          4
# ...       ...  ...        ...        ...        ...        ...        ...
# 10077      79  ...          7          7         13         15         13
# 3280      161  ...         66         60         58         56        196
# 3472      151  ...        131        153        162        161        157
# 6192      158  ...        108        107        100         88         80
# 10780      51  ...         63         72         74         73         74
#
#        Pixel9996  Pixel9997  Pixel9998  Pixel9999  Pixel10000
# 11482        213        174         60         63          58
# 5323           1          4         24         32          33
# 824            0          0          0          0           0
# 8833          36          0          0          0           0
# 1830           3          1          0          0           0
# ...          ...        ...        ...        ...         ...
# 10077         12         10          7         11          15
# 3280         247        241        243        242         240
# 3472         149        140        130        112         100
# 6192          81         87         84         84         104
# 10780         75         71         67         64          64
#
# [7300 rows x 10001 columns]
# Validation Data:
#        Label  Pixel1  Pixel2  Pixel3  Pixel4  Pixel5  Pixel6  Pixel7  Pixel8  \
# 10011     83     254     249     220     229     255     244     217     233
# 300        3     255     255     255     255     255     255     255     255
# 2034      17      77      80      83      85      86      87      89      90
# 1233      11      38      38      42      47      40      82      85      74
# 5910      47      90      83      88     102     102      94      90      90
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 1783      15     204     209     211     209     206     208     211     213
# 8081      66       3       2       2       2      18      26      25      26
# 8019      65      32      51      71      78      53      35      42      34
# 10778     90     196     196     196     196     197     197     197     197
# 16         1      44      44      45      45      46      46      46      46
#
#        Pixel9  ...  Pixel9991  Pixel9992  Pixel9993  Pixel9994  Pixel9995  \
# 10011     254  ...         77         79         78         80         85
# 300       255  ...        204        209        209        203        220
# 2034       95  ...        204        204        204        200        196
# 1233      157  ...        168        110          7         31         35
# 5910       88  ...         87         58         55         56         54
# ...       ...  ...        ...        ...        ...        ...        ...
# 1783      197  ...        206        200        205        206        196
# 8081       30  ...          1          4         11          2         27
# 8019       49  ...          4          4          4          4          4
# 10778     198  ...        171        197        155        120        104
# 16         45  ...         41         41         41         40         40
#
#        Pixel9996  Pixel9997  Pixel9998  Pixel9999  Pixel10000
# 10011         91         93         93         93          93
# 300          226        242        253        255         255
# 2034         185        177        177        171         165
# 1233          19         31          9         38          55
# 5910          56         55         55         55          55
# ...          ...        ...        ...        ...         ...
# 1783         186        194        190        116          95
# 8081         157        147        148        149         149
# 8019           4          5          5          5           5
# 10778        160        210        202        192         186
# 16            39         40         39         38          38
#
# [2433 rows x 10001 columns]
# Test Data:
#       Label  Pixel1  Pixel2  Pixel3  Pixel4  Pixel5  Pixel6  Pixel7  Pixel8  \
# 733       7      25      26      27      26      27      29      30      29
# 1274     11     213     213     212     213     215     217     219     219
# 6361     51     129     135     110      79     110     139     140     140
# 9841     81       8       8       8       8       8       9       9       9
# 8232     67      64      69      89      89      73      93     148     130
# ...     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 421       4       0       0       1       0       5      84     131     114
# 5145     42     249     249     249     249     249     249     249     249
# 5191     42     168     168     168     168     168     168     168     168
# 5419     44      60      61      62      60      60      61      61      60
# 9893     82      13      11      11      16      25      30      24      11
#
#       Pixel9  ...  Pixel9991  Pixel9992  Pixel9993  Pixel9994  Pixel9995  \
# 733       33  ...        183        183        184        184        185
# 1274     223  ...        247        250        251        249        248
# 6361     139  ...         20         24         22         16         18
# 9841       8  ...          8          7          7          9         11
# 8232     110  ...        180        175        171        179        184
# ...      ...  ...        ...        ...        ...        ...        ...
# 421      125  ...        151        165        155        133        143
# 5145     249  ...        134        119        113        128        160
# 5191     169  ...         89        103        158        154        172
# 5419      59  ...        145        147        151        153        156
# 9893      18  ...          2          2          2          2          2
#
#       Pixel9996  Pixel9997  Pixel9998  Pixel9999  Pixel10000
# 733         185        185        185        185         185
# 1274        249        249        249        250         251
# 6361         17         20         24         28          28
# 9841         12         16         20         19          16
# 8232        201        186        183        166         122
# ...         ...        ...        ...        ...         ...
# 421         129        163        143        154         159
# 5145        128        137        153        162         159
# 5191        194        178        149        174         185
# 5419        162        162        163        165         169
# 9893          1          1          1          1           1
#
# [2434 rows x 10001 columns]
